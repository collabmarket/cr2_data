# %% [markdown]
# ## Ejecutar cr2 carga Variables mensuales:
#
# - prec = 'Precipitacion'
# - caud = 'Caudal'
# - temp = 'Temperatura'
# - tmax = 'Temperatura max'
# - tmin = 'Temperatura min'

# %%
# Equivalente a lo siguiente
from cr2 import *

prec = Cr2('monthly', 'p', 'data.json')
caud = Cr2('monthly', 'q', 'data.json')
temp = Cr2('monthly', 't', 'data.json')
tmin = Cr2('monthly', 'tmin', 'data.json')
tmax = Cr2('monthly', 'tmax', 'data.json')

# %matplotlib inline

# %%
### Listados de métodos para objeto 'prec'
print dir(caud)
# Out:
# ['__doc__', '__init__', '__module__', 'busca', 'df', 'filename', 'get_df', 'get_meta', 'iname', 'kname', 'meta', 'open_sources', 'plot_annual', 'plot_month', 'plot_simple', 'units', 'var', 'varname']

# %% [markdown]
# ### Buscar Estacion por 'nombre'

# %%
# Estaciones fluviométricas cercanas a la desembocadura

station_cod = ['01211001', '01211002', # Lluta
              '01310003', # San Jose
              '01410005', # Rio Codpa
              '01502002', # Rio Camarones
              '01710001', # Quebrada Camigna
              '01720001', # Rio Aroma
              '01730005', # Quebrada Tarapaca
              '02120001', # Rio Loa
              '03453001', # Rio Copiapo
              '03826001', # Rio Huasco
              '04335001', # Rio Elqui
              '04558001', # Rio Limari
              '04556001', # Estero Punitaqui
              '04730001', # Rio Choapa
              '04902001', # Rio Quilimari
              '05120001', # Rio Petorca
              '05221002', # Rio Ligua
              '05320001', # Estero Quintero
              '05427003', # Estero De Limache
              '05426002', # Rio Aconcagua
              '05741001', '05746001', # Estero Puangue
              '05748001', # Rio Maipo
              '06056001', # Rio Rapel
              '06132001', # Estero Nilahue
              '07123001', # Rio Mataquito
              '07383001', # Rio Maule
              '07400001', # Rio Loanco
              '07337001', # Rio Tutuven
              '07336001', # Rio Cauquenes
              '08144001', # Rio Lonquen
              '08141001', # Rio Itata
              '08210001', # Rio Pingueral
              '08220001', # Rio Andalien
              '08394001', # Rio Biobio
              '08430001', # Rio Laraquete
              '08530001', # Rio Carampangue
              '08822001', # Rio Tucapel
              '09118001', # Rio Cholchol
              '09140001', # Rio Cautin
              '09437001', # Rio Tolten
              '10401001', # Rio Tranallaguin
              ]

# %%
aux = caud.meta.T
aux['indice'] = aux.index
aux = aux.set_index('codigo_estacion').loc[station_cod,:]
aux = aux[aux.cantidad_observaciones > 60]

# %%
for s in aux.indice.values:
    caud.plot_annual(s, figsize=(15,2))

# %%
for s in aux.indice.values:
    caud.plot_month(s, figsize=(15,2))
